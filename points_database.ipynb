# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/reviews_analysis')

# %%
points_data = pd.read_csv('1000points.csv', encoding = 'utf-8')
points_data.head()
# Out:
#              id                                           link  \
# 0    1347737832    https://yandex.ru/maps/org/ozon/1347737832/
# 1   13851635604   https://yandex.ru/maps/org/ozon/13851635604/
# 2   39673708169   https://yandex.ru/maps/org/ozon/39673708169/
# 3   78580824462   https://yandex.ru/maps/org/ozon/78580824462/
# 4  129607274504  https://yandex.ru/maps/org/ozon/129607274504/
#
#            coordinates                             address  stars
# 0  30.320252,59.962266            Большая Монетная ул., 16    4.7
# 1  30.317793,59.928854                    Спасский пер., 5    4.0
# 2  30.336890,59.934725  Малая Садовая ул., 3/54, подъезд 8    4.0
# 3  30.353562,59.930185               ул. Марата, 5, этаж 2    4.2
# 4  30.311988,59.927947               Гражданская ул., 17/8    4.4

# %%
points_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           1001 non-null   int64
#  1   link         1001 non-null   object
#  2   coordinates  1001 non-null   object
#  3   address      1001 non-null   object
#  4   stars        996 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 39.2+ KB

# %%
def count_duplicates(df):
  return df.groupby(df.columns.tolist(), as_index= False ).size()

# %%
def filter_duplicates(df):
  ndf = count_duplicates(df)
  return ndf.drop(['size'], axis=1)

# %%
ndf = count_duplicates(points_data)
ndf[ndf['size']>1]
# Out:
#                id                                           link  \
# 4      1779572472    https://yandex.ru/maps/org/ozon/1779572472/
# 11     8902031704    https://yandex.ru/maps/org/ozon/8902031704/
# 16    10920123581   https://yandex.ru/maps/org/ozon/10920123581/
# 17    11135826610   https://yandex.ru/maps/org/ozon/11135826610/
# 21    14227586211   https://yandex.ru/maps/org/ozon/14227586211/
# ..            ...                                            ...
# 388  234687291913  https://yandex.ru/maps/org/ozon/234687291913/
# 395  237629912731  https://yandex.ru/maps/org/ozon/237629912731/
# 398  239698987056  https://yandex.ru/maps/org/ozon/239698987056/
# 400  240997098425  https://yandex.ru/maps/org/ozon/240997098425/
# 402  241905718312  https://yandex.ru/maps/org/ozon/241905718312/
#
#              coordinates                                         address  \
# 4    30.316132,59.925351                                 пер. Бринько, 4
# ...

# %%
points = filter_duplicates(points_data)
points
# Out:
#                id                                           link  \
# 0      1276123110    https://yandex.ru/maps/org/ozon/1276123110/
# 1      1347737832    https://yandex.ru/maps/org/ozon/1347737832/
# 2      1356077836    https://yandex.ru/maps/org/ozon/1356077836/
# 3      1755157586    https://yandex.ru/maps/org/ozon/1755157586/
# 4      1779572472    https://yandex.ru/maps/org/ozon/1779572472/
# ..            ...                                            ...
# 400  240997098425  https://yandex.ru/maps/org/ozon/240997098425/
# 401  241806189646  https://yandex.ru/maps/org/ozon/241806189646/
# 402  241905718312  https://yandex.ru/maps/org/ozon/241905718312/
# 403  243668942076  https://yandex.ru/maps/org/ozon/243668942076/
# 404  245536924647  https://yandex.ru/maps/org/ozon/245536924647/
#
#              coordinates                                  address  stars
# 0    30.300854,60.002297  Коломяжский просп., 15, корп. 2, этаж 1    4.4
# ...

# %%
points.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405 entries, 0 to 404
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           405 non-null    int64
#  1   link         405 non-null    object
#  2   coordinates  405 non-null    object
#  3   address      405 non-null    object
#  4   stars        405 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 15.9+ KB

# %%
points.to_csv('ozon_points.csv', index=False, encoding='utf-8')
