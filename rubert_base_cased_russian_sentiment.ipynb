# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/reviews_analysis')

# %%
import pandas as pd
from datetime import datetime

# %%
def count_duplicates(df):
  return df.groupby(df.columns.tolist(), as_index= False).size()

# %%
def filter_duplicates(df):
  ndf = count_duplicates(df)
  return ndf.drop(['size'], axis=1)

# %%
reviews = pd.read_csv('all_reviews.csv', encoding='utf-8', parse_dates=['date'], date_format="%Y-%m-%d %H:%M:%S.%f")

# %%
reviews.head()
# Out:
#            id                    date  stars  \
# 0  1276123110 2024-01-13 08:17:29.661    5.0
# 1  1276123110 2024-04-04 13:23:17.859    5.0
# 2  1276123110 2023-01-01 12:19:35.464    4.0
# 3  1276123110 2023-05-09 10:59:03.823    5.0
# 4  1276123110 2023-11-09 16:21:06.131    5.0
#
#                                          review_text
# 0  У меня к озону, как к сервису, и конкретно к э...
# 1  Очень хороший пункт, удобно расположен, чисто,...
# 2  Пункт выдачи удобно расположен, очень легко на...
# 3  Все отлично, расположение, чисто, просторно, н...
# 4  хороший пункт, приятная работница, заказы полу...

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12221 entries, 0 to 12220
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           12221 non-null  int64
#  1   date         12221 non-null  datetime64[ns]
#  2   stars        12218 non-null  float64
#  3   review_text  12219 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 382.0+ KB

# %%
def find_NaN(df):
  return df[df.isna().any(axis=1)]

# %%
find_NaN(reviews)
# Out:
#                  id                    date  stars  \
# 1708    25010521811 2024-03-26 16:45:23.734    5.0
# 4413    74794040308 2024-06-05 19:38:31.052    NaN
# 5152    88497708729 2022-09-16 19:22:52.779    NaN
# 10562  207911795530 2024-02-06 13:21:56.288    5.0
# 11248  221560574924 2021-06-26 17:28:32.749    NaN
#
#                                              review_text
# 1708                                                 NaN
# 4413   Здравствуйте. Хочу пожаловаться на выданный за...
# 5152   30 секунд и все что заказал получил... Ходить ...
# 10562                                                NaN
# 11248                                  Небольшой, уютный

# %%
filtered_reviews = reviews.dropna()
filtered_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12216 entries, 0 to 12220
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           12216 non-null  int64
#  1   date         12216 non-null  datetime64[ns]
#  2   stars        12216 non-null  float64
#  3   review_text  12216 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 477.2+ KB

# %%
from transformers import pipeline

# %%
model = pipeline(model="seara/rubert-base-cased-russian-sentiment", top_k=None)

# %%
def get_value_by_key(l, key):
  for d in l:
    if d.get('label') == key:
      return d.get('score')

  return 0

# %%
def get_sentiment_analysis(data, model):
  df = data.copy()

  results = model.predict(df['review_text'].to_list())
  keys = ['positive', 'neutral', 'negative']
  for key in keys:
    df[key] = [get_value_by_key(res, key) for res in results]

  return df

# %%
filtered_reviews['text_length'] = filtered_reviews['review_text'].str.len()

# %%
filter_len = filtered_reviews[filtered_reviews['text_length'] < 2000]

# %%
filtered_reviews[filtered_reviews['text_length'] > 2000]
# Out:
#                  id                    date  stars  \
# 57       1347737832 2022-08-18 17:49:30.390    1.0
# 2540    44551846782 2021-12-25 09:21:03.003    5.0
# 3827    68721290739 2022-12-27 18:33:05.070    1.0
# 6241   120290578182 2024-03-24 12:04:09.386    1.0
# 7787   156334246917 2023-01-27 13:19:03.955    1.0
# 11366  227211064249 2022-01-11 14:39:39.372    1.0
#
#                                              review_text  text_length
# 57     Снова оставлю свой отпечаток тут в виде текста...         5807
# 2540   Почитала я комментарии,и понимаю на сколько ко...         2215
# 3827   Всем добрый день. Плюсы... ничего не могу сказ...         2251
# 6241   Уже несколько лет забираю покупки в «Озоне» по...         2823
# 7787   САМЫЙ ТОРМОЗНУТЫЙ ПУНКТ. Добрый день, пишу жал...         2325
# 11366  Так-же отпишусь, отзыв не к пункту выдачи, а о...         2212

# %%
sent_rev = get_sentiment_analysis(filter_len, model)
sent_rev
# Out:
#                  id                    date  stars  \
# 0        1276123110 2024-01-13 08:17:29.661    5.0
# 1        1276123110 2024-04-04 13:23:17.859    5.0
# 2        1276123110 2023-01-01 12:19:35.464    4.0
# 3        1276123110 2023-05-09 10:59:03.823    5.0
# 4        1276123110 2023-11-09 16:21:06.131    5.0
# ...             ...                     ...    ...
# 12216  245536924647 2022-05-03 05:31:04.866    5.0
# 12217  245536924647 2022-12-18 13:21:45.710    5.0
# 12218  245536924647 2021-10-05 16:58:36.684    5.0
# 12219  245536924647 2022-05-11 15:30:47.822    5.0
# 12220  245536924647 2021-07-28 10:46:02.934    5.0
#
#                                              review_text  text_lenght  \
# 0      У меня к озону, как к сервису, и конкретно к э...          331
# 1      Очень хороший пункт, удобно расположен, чисто,...           67
# 2      Пункт выдачи удобно расположен, очень легко на...          257
# 3      Все отлично, расположение, чисто, просторно, н...           76
# 4      хороший пункт, приятная работница, заказы полу...           68
# ...                                                  ...          ...
# 12216                               Быстрое обслуживание           20
# 12217                                        Всё по делу           11
# 12218                       Высокий уровень обслуживания           28
# 12219                                       Спасибо Оzon           12
# 12220                                        Найти легко           11
#
#        positive   neutral  negative
# 0      0.400817  0.547377  0.051806
# 1      0.996105  0.002512  0.001383
# 2      0.327667  0.642293  0.030039
# 3      0.996277  0.002724  0.000999
# 4      0.996340  0.002836  0.000824
# ...         ...       ...       ...
# 12216  0.719184  0.274255  0.006561
# 12217  0.016143  0.968565  0.015291
# 12218  0.305603  0.668827  0.025571
# 12219  0.977438  0.012087  0.010476
# 12220  0.535974  0.449494  0.014531
#
# [12210 rows x 8 columns]

# %% [markdown]
# 31 minutes

# %%
def get_marks(data):
  df = data.copy()
  s = df['positive'] + df['neutral'] + df['negative']
  df['mark'] = (5*df['positive'] + 4*df['neutral'] + 1*df['negative'])/s
  return df

# %%
estimated = get_marks(sent_rev)
estimated
# Out:
#                  id                    date  stars  \
# 0        1276123110 2024-01-13 08:17:29.661    5.0
# 1        1276123110 2024-04-04 13:23:17.859    5.0
# 2        1276123110 2023-01-01 12:19:35.464    4.0
# 3        1276123110 2023-05-09 10:59:03.823    5.0
# 4        1276123110 2023-11-09 16:21:06.131    5.0
# ...             ...                     ...    ...
# 12216  245536924647 2022-05-03 05:31:04.866    5.0
# 12217  245536924647 2022-12-18 13:21:45.710    5.0
# 12218  245536924647 2021-10-05 16:58:36.684    5.0
# 12219  245536924647 2022-05-11 15:30:47.822    5.0
# 12220  245536924647 2021-07-28 10:46:02.934    5.0
#
#                                              review_text  text_lenght  \
# 0      У меня к озону, как к сервису, и конкретно к э...          331
# 1      Очень хороший пункт, удобно расположен, чисто,...           67
# 2      Пункт выдачи удобно расположен, очень легко на...          257
# 3      Все отлично, расположение, чисто, просторно, н...           76
# 4      хороший пункт, приятная работница, заказы полу...           68
# ...                                                  ...          ...
# 12216                               Быстрое обслуживание           20
# 12217                                        Всё по делу           11
# 12218                       Высокий уровень обслуживания           28
# 12219                                       Спасибо Оzon           12
# 12220                                        Найти легко           11
#
#        positive   neutral  negative      mark
# 0      0.400817  0.547377  0.051806  4.245399
# 1      0.996105  0.002512  0.001383  4.991957
# 2      0.327667  0.642293  0.030039  4.237549
# 3      0.996277  0.002724  0.000999  4.993279
# 4      0.996340  0.002836  0.000824  4.993867
# ...         ...       ...       ...       ...
# 12216  0.719184  0.274255  0.006561  4.699502
# 12217  0.016143  0.968565  0.015291  3.970269
# 12218  0.305603  0.668827  0.025571  4.228890
# 12219  0.977438  0.012087  0.010476  4.946011
# 12220  0.535974  0.449494  0.014531  4.492381
#
# [12210 rows x 9 columns]

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(estimated['stars'], estimated['mark'])
# Out:
# 0.4357123176483525

# %%
estimated.drop(['text_length'], axis = 1).to_csv('rubert-base-cased.csv', encoding='utf-8')
